# %%
import pandas as pd
import os

os.chdir('C:/Users/natha/Desktop/Thesis/Storm_Database/VONGFONG/2020051118/MyDocuments/')

df = pd.read_csv('HS_H08_20200511_1800_B07_FLDK_R20_S0110.DAT', encoding= 'unicode_escape', on_bad_lines='skip')
df
# Out:
#
#
# Ó°>
# 1
# 2                                                     /
# 3     ?ý>è>è>ç>à>è>é>Ù>Ê>Ù>Þ>Ì>¸>µ>¼>½>½>¯>´>É>é>í>Ü...
# 4             ?í>¨>x>R>]>`>X>M>l>B>7>>Ã>Ó>ù>ÿ>ü>ú>ó>ù>
# ...                                                 ...
# 4373                                                  ?
# 4374  =û<$=u= =ä=>>$>ö=Ë=³=¦=¸==ª=ÿ==q<<\=>¨=G...
# 4375                          >ß=à==­<;Ç:Õ:;6;¯;ç;
# <
# 4376  <;Ú;
# <<v<Þ<Ê<¨<¾<j=R=x<P<4<Ð;æ;<©<e<M<<<...
# 4377  >Ì==±=>¾>"??¨>R>ò>¡?Ò?Ï?Ð?Ô?Õ?×?Õ?Ø?Ú?Ø?Ù?Ý...
#
# [4378 rows x 1 columns]

# %%
from satpy import Scene, MultiScene 
import glob as glob

os.chdir('D:/Thesis/Nuri/06_12/00/')

lat = 16.4
lon = 119.4
bbox = (lon+5, lat+5, lon-5, lat-5)

mscn1 = MultiScene.from_files(glob.glob('*.DAT'), reader='ahi_hsd')
mscn1.load(['B07','B11','B13','B14','B15'])
mscn2 = mscn1.crop(ll_bbox=bbox)

mscn2.save_datasets(writer='cf', base_dir = 'D:/Thesis/Nuri/Cropped/')

os.chdir('D:/Thesis/Nuri/06_12/06/')

lat = 16.9
lon = 118.2
bbox = (lon+5, lat+5, lon-5, lat-5)

mscn2 = MultiScene.from_files(glob.glob('*.DAT'), reader='ahi_hsd')
mscn2.load(['B07','B11','B13','B14','B15'])
mscn3 = mscn2.crop(ll_bbox=bbox)

mscn3.save_datasets(writer='cf', base_dir = 'D:/Thesis/Nuri/Cropped/')

os.chdir('D:/Thesis/Nuri/06_12/12/')

lat = 17.4
lon = 117.2
bbox = (lon+5, lat+5, lon-5, lat-5)

mscn3 = MultiScene.from_files(glob.glob('*.DAT'), reader='ahi_hsd')
mscn3.load(['B07','B11','B13','B14','B15'])
mscn4 = mscn3.crop(ll_bbox=bbox)

mscn4.save_datasets(writer='cf', base_dir = 'D:/Thesis/Nuri/Cropped/')

os.chdir('D:/Thesis/Nuri/06_12/18/')

lat = 17.9
lon = 116.2
bbox = (lon+5, lat+5, lon-5, lat-5)

mscn4 = MultiScene.from_files(glob.glob('*.DAT'), reader='ahi_hsd')
mscn4.load(['B07','B11','B13','B14','B15'])
mscn5 = mscn4.crop(ll_bbox=bbox)

mscn5.save_datasets(writer='cf', base_dir = 'D:/Thesis/Nuri/Cropped/')

os.chdir('D:/Thesis/Nuri/06_13/00/')

lat = 18.5
lon = 115.4
bbox = (lon+5, lat+5, lon-5, lat-5)

mscn5 = MultiScene.from_files(glob.glob('*.DAT'), reader='ahi_hsd')
mscn5.load(['B07','B11','B13','B14','B15'])
mscn6 = mscn5.crop(ll_bbox=bbox)

mscn6.save_datasets(writer='cf', base_dir = 'D:/Thesis/Nuri/Cropped/')

os.chdir('D:/Thesis/Nuri/06_13/06/')

lat = 19.2
lon = 114.6
bbox = (lon+5, lat+5, lon-5, lat-5)

mscn6 = MultiScene.from_files(glob.glob('*.DAT'), reader='ahi_hsd')
mscn6.load(['B07','B11','B13','B14','B15'])
mscn7 = mscn6.crop(ll_bbox=bbox)

mscn7.save_datasets(writer='cf', base_dir = 'D:/Thesis/Nuri/Cropped/')

os.chdir('D:/Thesis/Nuri/06_13/12/')

lat = 19.9
lon = 113.9
bbox = (lon+5, lat+5, lon-5, lat-5)

mscn7 = MultiScene.from_files(glob.glob('*.DAT'), reader='ahi_hsd')
mscn7.load(['B07','B11','B13','B14','B15'])
mscn8 = mscn7.crop(ll_bbox=bbox)

mscn8.save_datasets(writer='cf', base_dir = 'D:/Thesis/Nuri/Cropped/')

os.chdir('D:/Thesis/Nuri/06_13/18/')

lat = 20.7
lon = 113.1
bbox = (lon+5, lat+5, lon-5, lat-5)

mscn8 = MultiScene.from_files(glob.glob('*.DAT'), reader='ahi_hsd')
mscn8.load(['B07','B11','B13','B14','B15'])
mscn9 = mscn8.crop(ll_bbox=bbox)

mscn9.save_datasets(writer='cf', base_dir = 'D:/Thesis/Nuri/Cropped/')

os.chdir('D:/Thesis/Nuri/06_14/00/')

lat = 21.4
lon = 112.2
bbox = (lon+5, lat+5, lon-5, lat-5)

mscn9 = MultiScene.from_files(glob.glob('*.DAT'), reader='ahi_hsd')
mscn9.load(['B07','B11','B13','B14','B15'])
mscn10 = mscn9.crop(ll_bbox=bbox)

mscn10.save_datasets(writer='cf', base_dir = 'D:/Thesis/Nuri/Cropped/')

os.chdir('D:/Thesis/Nuri/06_14/06/')

lat = 22.2
lon = 111.3
bbox = (lon+5, lat+5, lon-5, lat-5)

mscn10 = MultiScene.from_files(glob.glob('*.DAT'), reader='ahi_hsd')
mscn10.load(['B07','B11','B13','B14','B15'])
mscn11 = mscn10.crop(ll_bbox=bbox)

mscn11.save_datasets(writer='cf', base_dir = 'D:/Thesis/Nuri/Cropped/')
# Out:
# c:\Users\natha\anaconda3\envs\metpy1\lib\site-packages\dask\core.py:119: RuntimeWarning: invalid value encountered in log
#   return func(*(_execute_task(a, cache) for a in args))
# c:\Users\natha\anaconda3\envs\metpy1\lib\site-packages\dask\core.py:119: RuntimeWarning: invalid value encountered in log
#   return func(*(_execute_task(a, cache) for a in args))
# c:\Users\natha\anaconda3\envs\metpy1\lib\site-packages\dask\core.py:119: RuntimeWarning: invalid value encountered in log
#   return func(*(_execute_task(a, cache) for a in args))
# c:\Users\natha\anaconda3\envs\metpy1\lib\site-packages\dask\core.py:119: RuntimeWarning: invalid value encountered in log
#   return func(*(_execute_task(a, cache) for a in args))
# c:\Users\natha\anaconda3\envs\metpy1\lib\site-packages\dask\core.py:119: RuntimeWarning: invalid value encountered in log
#   return func(*(_execute_task(a, cache) for a in args))
# ...

# %%
from satpy import Scene, MultiScene 
import glob

# Best Track Central Lat/Lon

lat = 17.9
lon = 116.2
bbox = (lon+5, lat+5, lon-5, lat-5)

# 2020051118

os.chdir('D:/Thesis/Nuri/06_12/18/TEST3/')

scn = Scene(filenames=glob.glob('*.dat'), reader="ahi_hsd")
scn.available_dataset_names()
scn.load(["B07"])
scn2 = scn.crop(ll_bbox=bbox)

scn2.save_datasets(writer='simple_image', base_dir = 'D:/Thesis/Nuri/TEST/')
# Out:
# c:\Users\natha\anaconda3\envs\metpy1\lib\site-packages\dask\core.py:119: RuntimeWarning: invalid value encountered in log
#   return func(*(_execute_task(a, cache) for a in args))

# %%
import netCDF4
import os

os.chdir('D:/Thesis/Nuri/Cropped/')
file2read = netCDF4.Dataset('B14_20200612_022000.nc','r')
print(file2read)
file2read.close()
# Out:
# <class 'netCDF4._netCDF4.Dataset'>
# root group (NETCDF4 data model, file format HDF5):
#     history: Created by pytroll/satpy on 2023-07-16 00:39:35.797725
#     Conventions: CF-1.7
#     dimensions(sizes): y(517), x(531)
#     variables(dimensions): int32 FLDK(), float64 y(y), float64 x(x), float64 longitude(y, x), float64 latitude(y, x), float32 B07(y, x), float32 B11(y, x), float32 B13(y, x), float32 B14(y, x), float32 B15(y, x)
#     groups:
